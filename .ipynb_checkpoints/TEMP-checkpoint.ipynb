# %%
import numpy as np

def sigmoid(x):
    return 1/(1 + np.exp(-x))

class LinearModel(object):
    """Base class for linear models"""
    def __init__(self, step_size=0.2, max_iter=100, eps=1e-6, theta_0=None, vebose=True):
        self.step_size = step_size
        self.max_iter = max_iter
        self.eps = eps
        self.theta = theta_0
        self.verbose = verbose

    def fit(self, X, y):
        pass

    def predict(self, X):
        pass

class BatchGradientAscentLogisticRegression(LinearModel):

    def fit(self, X, y):
        m, n = X.shape
        self.theta = np.zeros(n)

        while True:
            theta_old = np.copy(self.theta)
            h = sigmoid(X @ self.theta)
            gradient = X.T @ (y - h) / m
            self.theta += self.step_size * gradient

            if np.linalg.norm(self.theta - theta_old, ord = 1) < self.eps:
                break

    def predict(self, X):
        return sigmoid(X @ self.theta)

if __name__ == "__main__" :
    
    m, n, t = map(int, input().split())

    X_train = np.array(input().split(), dtype=float)
    y_train = np.array(input().split(), dtype=float)
    X_pred = np.array(input().split(), dtype=float)

    model = BatchGradientAscentLogisticRegression()

    model.fit(X_train, y_train)

    y_pred = model.predict(X_pred)

    print(*[f"{x:.4f}" for x in model.theta])
    print(*[f"{x:.4f}" for x in y_pred])
