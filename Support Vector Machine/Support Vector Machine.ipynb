# %%
class SupportVectorMachine:

    def __init__(self, step_size=0.001, lambda_param=0.01, max_iters=1000):

        self.step_size = step_size
        self.max_iters = max_iters
        self.lambda_param = lambda_param
